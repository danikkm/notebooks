# %%
'''
pip install pyyaml
pip install easydict
pip install -U pytorch_warmup
''';

# %%
# !nvidia-smi
# Out:
# Sun Apr 18 20:58:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.67       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    29W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/jupyter/detr/transformers')

# %%
# !ls
# Out:
# checkpoint   coco-args.txt  logs    runs		    utils
# classes.txt  config.yaml    models  transformer_coco.ipynb

# %%
import os, sys
import yaml
import requests
from pathlib import Path

from easydict import EasyDict as edict

import numpy as np
import torch
from torch.cuda import amp
from torch.optim import AdamW
from torch.optim.lr_scheduler import StepLR
from torch.utils.data.dataloader import DataLoader
import torchvision.transforms as transforms

from models import DETR, SetCriterion
from utils.dataset import collateFunction, COCODataset
from utils.misc import MetricsLogger, saveArguments, logMetrics, cast2Float

from utils.plots import plot_images, plot_labels, plot_results, plot_evolution
from utils.general import increment_path

from tqdm.notebook import tqdm, trange

import matplotlib.pyplot as plt
from PIL import Image

# %load_ext autoreload
# %autoreload 2

# %%
CURRENT_PATH = os.path.join(os.getcwd())
BASE_PATH = Path(CURRENT_PATH).parent
CONFIG = os.path.join(CURRENT_PATH, 'config.yaml')

# %%
CURRENT_PATH
# Out:
# '/content/drive/My Drive/jupyter/detr/transformers'

# %%
def parse_config():
    with open(CONFIG, 'r') as stream:
        try:
            return yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            raise ValueError("Failed to parse config requried")

# %%
args = edict(parse_config())

# %%
args.device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
saveArguments(args, args.taskName)
torch.manual_seed(1337)
device = torch.device(args.device)

# %%
# !unzip "/content/drive/My Drive/jupyter/detr/detr.zip" -d "/content/10k_coco";
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/10k_coco/8k_train/000000221547.jpg
#   inflating: /content/10k_coco/8k_train/000000221665.jpg
#   inflating: /content/10k_coco/8k_train/000000221725.jpg
#   inflating: /content/10k_coco/8k_train/000000221776.jpg
#   inflating: /content/10k_coco/8k_train/000000221829.jpg
#  extracting: /content/10k_coco/8k_train/000000221881.jpg
#  extracting: /content/10k_coco/8k_train/000000221903.jpg
#   inflating: /content/10k_coco/8k_train/000000221911.jpg
#   inflating: /content/10k_coco/8k_train/000000222056.jpg
#   inflating: /content/10k_coco/8k_train/000000222080.jpg
#   inflating: /content/10k_coco/8k_train/000000222245.jpg
#   inflating: /content/10k_coco/8k_train/000000222266.jpg
#   inflating: /content/10k_coco/8k_train/000000222295.jpg
#   inflating: /content/10k_coco/8k_train/000000222370.jpg
#   inflating: /content/10k_coco/8k_train/000000222472.jpg
#   inflating: /content/10k_coco/8k_train/000000222513.jpg
#   inflating: /content/10k_coco/8k_train/000000222517.jpg
#   inflating: /content/10k_coco/8k_train/000000222599.jpg
#  extracting: /content/10k_coco/8k_train/000000222635.jpg
#   inflating: /content/10k_coco/8k_train/000000222648.jpg
#  extracting: /content/10k_coco/8k_train/000000222664.jpg
#   inflating: /content/10k_coco/8k_train/000000222676.jpg
#   inflating: /content/10k_coco/8k_train/000000222831.jpg
#   inflating: /content/10k_coco/8k_train/000000222961.jpg
#   inflating: /content/10k_coco/8k_train/000000223014.jpg
#   inflating: /content/10k_coco/8k_train/000000223078.jpg
#   inflating: /content/10k_coco/8k_train/000000223091.jpg
#   inflating: /content/10k_coco/8k_train/000000223112.jpg
#  extracting: /content/10k_coco/8k_train/000000223122.jpg
#   inflating: /content/10k_coco/8k_train/000000223339.jpg
#  extracting: /content/10k_coco/8k_train/000000223357.jpg
#   inflating: /content/10k_coco/8k_train/000000223603.jpg
#   inflating: /content/10k_coco/8k_train/000000223612.jpg
#   inflating: /content/10k_coco/8k_train/000000223726.jpg
#   inflating: /content/10k_coco/8k_train/000000223755.jpg
#   inflating: /content/10k_coco/8k_train/000000223764.jpg
#  extracting: /content/10k_coco/8k_train/000000223766.jpg
#   inflating: /content/10k_coco/8k_train/000000223996.jpg
#  extracting: /content/10k_coco/8k_train/000000224012.jpg
#   inflating: /content/10k_coco/8k_train/000000224017.jpg
#   inflating: /content/10k_coco/8k_train/000000224047.jpg
#   inflating: /content/10k_coco/8k_train/000000224053.jpg
#  extracting: /content/10k_coco/8k_train/000000224112.jpg
#   inflating: /content/10k_coco/8k_train/000000224128.jpg
#   inflating: /content/10k_coco/8k_train/000000224304.jpg
#  extracting: /content/10k_coco/8k_train/000000224358.jpg
#   inflating: /content/10k_coco/8k_train/000000224476.jpg
#   inflating: /content/10k_coco/8k_train/000000224531.jpg
#  extracting: /content/10k_coco/8k_train/000000224711.jpg
#   inflating: /content/10k_coco/8k_train/000000224800.jpg
#   inflating: /content/10k_coco/8k_train/000000224878.jpg
#   inflating: /content/10k_coco/8k_train/000000225198.jpg
#   inflating: /content/10k_coco/8k_train/000000225215.jpg
#   inflating: /content/10k_coco/8k_train/000000225265.jpg
#  extracting: /content/10k_coco/8k_train/000000225281.jpg
#   inflating: /content/10k_coco/8k_train/000000225312.jpg
#   inflating: /content/10k_coco/8k_train/000000225393.jpg
#   inflating: /content/10k_coco/8k_train/000000225463.jpg
#   inflating: /content/10k_coco/8k_train/000000225808.jpg
#   inflating: /content/10k_coco/8k_train/000000225834.jpg
#   inflating: /content/10k_coco/8k_train/000000226008.jpg
#   inflating: /content/10k_coco/8k_train/000000226197.jpg
#   inflating: /content/10k_coco/8k_train/000000226224.jpg
#   inflating: /content/10k_coco/8k_train/000000226249.jpg
#  extracting: /content/10k_coco/8k_train/000000226254.jpg
#   inflating: /content/10k_coco/8k_train/000000226376.jpg
#   inflating: /content/10k_coco/8k_train/000000226518.jpg
#   inflating: /content/10k_coco/8k_train/000000226660.jpg
#  extracting: /content/10k_coco/8k_train/000000226705.jpg
#   inflating: /content/10k_coco/8k_train/000000226820.jpg
#   inflating: /content/10k_coco/8k_train/000000226848.jpg
#  extracting: /content/10k_coco/8k_train/000000227003.jpg
#   inflating: /content/10k_coco/8k_train/000000227032.jpg
#   inflating: /content/10k_coco/8k_train/000000227033.jpg
#   inflating: /content/10k_coco/8k_train/000000227250.jpg
#   inflating: /content/10k_coco/8k_train/000000227269.jpg
#   inflating: /content/10k_coco/8k_train/000000227422.jpg
#   inflating: /content/10k_coco/8k_train/000000227428.jpg
#  extracting: /content/10k_coco/8k_train/000000227453.jpg
#  extracting: /content/10k_coco/8k_train/000000227550.jpg
#  extracting: /content/10k_coco/8k_train/000000227558.jpg
#   inflating: /content/10k_coco/8k_train/000000227567.jpg
#   inflating: /content/10k_coco/8k_train/000000227582.jpg
#   inflating: /content/10k_coco/8k_train/000000227606.jpg
#   inflating: /content/10k_coco/8k_train/000000227638.jpg
#   inflating: /content/10k_coco/8k_train/000000227657.jpg
#   inflating: /content/10k_coco/8k_train/000000227689.jpg
#  extracting: /content/10k_coco/8k_train/000000227769.jpg
#  extracting: /content/10k_coco/8k_train/000000227806.jpg
#  extracting: /content/10k_coco/8k_train/000000227893.jpg
#   inflating: /content/10k_coco/8k_train/000000228000.jpg
#   inflating: /content/10k_coco/8k_train/000000228071.jpg
#   inflating: /content/10k_coco/8k_train/000000228121.jpg
#   inflating: /content/10k_coco/8k_train/000000228122.jpg
#  extracting: /content/10k_coco/8k_train/000000228185.jpg
#  extracting: /content/10k_coco/8k_train/000000228335.jpg
#   inflating: /content/10k_coco/8k_train/000000228356.jpg
#  extracting: /content/10k_coco/8k_train/000000228411.jpg
#   inflating: /content/10k_coco/8k_train/000000228413.jpg
#   inflating: /content/10k_coco/8k_train/000000228477.jpg
#  extracting: /content/10k_coco/8k_train/000000228560.jpg
#   inflating: /content/10k_coco/8k_train/000000228644.jpg
#   inflating: /content/10k_coco/8k_train/000000228857.jpg
#  extracting: /content/10k_coco/8k_train/000000228867.jpg
#  extracting: /content/10k_coco/8k_train/000000228910.jpg
#   inflating: /content/10k_coco/8k_train/000000228919.jpg
#   inflating: /content/10k_coco/8k_train/000000228920.jpg
#   inflating: /content/10k_coco/8k_train/000000229041.jpg
#   inflating: /content/10k_coco/8k_train/000000229132.jpg
#  extracting: /content/10k_coco/8k_train/000000229234.jpg
#   inflating: /content/10k_coco/8k_train/000000229267.jpg
#   inflating: /content/10k_coco/8k_train/000000229270.jpg
#  extracting: /content/10k_coco/8k_train/000000229342.jpg
#   inflating: /content/10k_coco/8k_train/000000229398.jpg
#   inflating: /content/10k_coco/8k_train/000000229427.jpg
#   inflating: /content/10k_coco/8k_train/000000229491.jpg
#  extracting: /content/10k_coco/8k_train/000000229813.jpg
#   inflating: /content/10k_coco/8k_train/000000229866.jpg
#   inflating: /content/10k_coco/8k_train/000000229870.jpg
#  extracting: /content/10k_coco/8k_train/000000229875.jpg
#   inflating: /content/10k_coco/8k_train/000000229940.jpg
#   inflating: /content/10k_coco/8k_train/000000229946.jpg
#   inflating: /content/10k_coco/8k_train/000000229962.jpg
#   inflating: /content/10k_coco/8k_train/000000229990.jpg
#   inflating: /content/10k_coco/8k_train/000000230119.jpg
#   inflating: /content/10k_coco/8k_train/000000230141.jpg
#   inflating: /content/10k_coco/8k_train/000000230190.jpg
#  extracting: /content/10k_coco/8k_train/000000230210.jpg
#  extracting: /content/10k_coco/8k_train/000000230245.jpg
#  extracting: /content/10k_coco/8k_train/000000230302.jpg
#   inflating: /content/10k_coco/8k_train/000000230548.jpg
#   inflating: /content/10k_coco/8k_train/000000230561.jpg
#  extracting: /content/10k_coco/8k_train/000000230665.jpg
#   inflating: /content/10k_coco/8k_train/000000230763.jpg
#   inflating: /content/10k_coco/8k_train/000000230851.jpg
#   inflating: /content/10k_coco/8k_train/000000230936.jpg
#   inflating: /content/10k_coco/8k_train/000000231079.jpg
#  extracting: /content/10k_coco/8k_train/000000231087.jpg
#   inflating: /content/10k_coco/8k_train/000000231104.jpg
#   inflating: /content/10k_coco/8k_train/000000231322.jpg
#  extracting: /content/10k_coco/8k_train/000000231338.jpg
#   inflating: /content/10k_coco/8k_train/000000231401.jpg
#   inflating: /content/10k_coco/8k_train/000000231538.jpg
#   inflating: /content/10k_coco/8k_train/000000231659.jpg
#   inflating: /content/10k_coco/8k_train/000000231758.jpg
#   inflating: /content/10k_coco/8k_train/000000231812.jpg
#   inflating: /content/10k_coco/8k_train/000000231846.jpg
#   inflating: /content/10k_coco/8k_train/000000231862.jpg
#   inflating: /content/10k_coco/8k_train/000000231881.jpg
#   inflating: /content/10k_coco/8k_train/000000232073.jpg
#   inflating: /content/10k_coco/8k_train/000000232118.jpg
#   inflating: /content/10k_coco/8k_train/000000232182.jpg
#  extracting: /content/10k_coco/8k_train/000000232245.jpg
#  extracting: /content/10k_coco/8k_train/000000232337.jpg
#   inflating: /content/10k_coco/8k_train/000000232358.jpg
#   inflating: /content/10k_coco/8k_train/000000232389.jpg
#  extracting: /content/10k_coco/8k_train/000000232627.jpg
#   inflating: /content/10k_coco/8k_train/000000232658.jpg
#   inflating: /content/10k_coco/8k_train/000000232660.jpg
#  extracting: /content/10k_coco/8k_train/000000232746.jpg
#  extracting: /content/10k_coco/8k_train/000000232865.jpg
#   inflating: /content/10k_coco/8k_train/000000232954.jpg
#   inflating: /content/10k_coco/8k_train/000000233080.jpg
#   inflating: /content/10k_coco/8k_train/000000233102.jpg
#   inflating: /content/10k_coco/8k_train/000000233119.jpg
#   inflating: /content/10k_coco/8k_train/000000233146.jpg
#   inflating: /content/10k_coco/8k_train/000000233233.jpg
#   inflating: /content/10k_coco/8k_train/000000233272.jpg
#  extracting: /content/10k_coco/8k_train/000000233348.jpg
#   inflating: /content/10k_coco/8k_train/000000233379.jpg
#   inflating: /content/10k_coco/8k_train/000000233575.jpg
#   inflating: /content/10k_coco/8k_train/000000233660.jpg
#   inflating: /content/10k_coco/8k_train/000000233677.jpg
#  extracting: /content/10k_coco/8k_train/000000233697.jpg
#   inflating: /content/10k_coco/8k_train/000000233786.jpg
#  extracting: /content/10k_coco/8k_train/000000233873.jpg
#   inflating: /content/10k_coco/8k_train/000000233878.jpg
#  extracting: /content/10k_coco/8k_train/000000233977.jpg
#  extracting: /content/10k_coco/8k_train/000000234020.jpg
#  extracting: /content/10k_coco/8k_train/000000234147.jpg
#   inflating: /content/10k_coco/8k_train/000000234234.jpg
#  extracting: /content/10k_coco/8k_train/000000234251.jpg
#   inflating: /content/10k_coco/8k_train/000000234516.jpg
#   inflating: /content/10k_coco/8k_train/000000234612.jpg
#   inflating: /content/10k_coco/8k_train/000000234786.jpg
#   inflating: /content/10k_coco/8k_train/000000234903.jpg
#   inflating: /content/10k_coco/8k_train/000000234934.jpg
#   inflating: /content/10k_coco/8k_train/000000234945.jpg
#  extracting: /content/10k_coco/8k_train/000000234986.jpg
#   inflating: /content/10k_coco/8k_train/000000235061.jpg
#   inflating: /content/10k_coco/8k_train/000000235091.jpg
#   inflating: /content/10k_coco/8k_train/000000235245.jpg
#   inflating: /content/10k_coco/8k_train/000000235274.jpg
#   inflating: /content/10k_coco/8k_train/000000235430.jpg
#   inflating: /content/10k_coco/8k_train/000000235446.jpg
#   inflating: /content/10k_coco/8k_train/000000235466.jpg
#   inflating: /content/10k_coco/8k_train/000000235499.jpg
#  extracting: /content/10k_coco/8k_train/000000235517.jpg
#   inflating: /content/10k_coco/8k_train/000000235564.jpg
#  extracting: /content/10k_coco/8k_train/000000235759.jpg
#   inflating: /content/10k_coco/8k_train/000000235802.jpg
#   inflating: /content/10k_coco/8k_train/000000235844.jpg
#   inflating: /content/10k_coco/8k_train/000000235916.jpg
#   inflating: /content/10k_coco/8k_train/000000236052.jpg
#   inflating: /content/10k_coco/8k_train/000000236087.jpg
#   inflating: /content/10k_coco/8k_train/000000236224.jpg
#   inflating: /content/10k_coco/8k_train/000000236226.jpg
#   inflating: /content/10k_coco/8k_train/000000236239.jpg
#   inflating: /content/10k_coco/8k_train/000000236268.jpg
#   inflating: /content/10k_coco/8k_train/000000236294.jpg
#  extracting: /content/10k_coco/8k_train/000000236316.jpg
#   inflating: /content/10k_coco/8k_train/000000236414.jpg
#   inflating: /content/10k_coco/8k_train/000000236432.jpg
#   inflating: /content/10k_coco/8k_train/000000236484.jpg
#   inflating: /content/10k_coco/8k_train/000000236556.jpg
#   inflating: /content/10k_coco/8k_train/000000236909.jpg
#   inflating: /content/10k_coco/8k_train/000000236954.jpg
#   inflating: /content/10k_coco/8k_train/000000236985.jpg
#   inflating: /content/10k_coco/8k_train/000000237000.jpg
#   inflating: /content/10k_coco/8k_train/000000237091.jpg
#   inflating: /content/10k_coco/8k_train/000000237160.jpg
#   inflating: /content/10k_coco/8k_train/000000237190.jpg
#   inflating: /content/10k_coco/8k_train/000000237230.jpg
#   inflating: /content/10k_coco/8k_train/000000237256.jpg
#   inflating: /content/10k_coco/8k_train/000000237271.jpg
#  extracting: /content/10k_coco/8k_train/000000237333.jpg
#   inflating: /content/10k_coco/8k_train/000000237363.jpg
#  extracting: /content/10k_coco/8k_train/000000237367.jpg
#  extracting: /content/10k_coco/8k_train/000000237505.jpg
#   inflating: /content/10k_coco/8k_train/000000237514.jpg
#   inflating: /content/10k_coco/8k_train/000000237561.jpg
#   inflating: /content/10k_coco/8k_train/000000237759.jpg
#   inflating: /content/10k_coco/8k_train/000000238086.jpg
#   inflating: /content/10k_coco/8k_train/000000238090.jpg
#   inflating: /content/10k_coco/8k_train/000000238172.jpg
#  extracting: /content/10k_coco/8k_train/000000238201.jpg
#   inflating: /content/10k_coco/8k_train/000000238212.jpg
#   inflating: /content/10k_coco/8k_train/000000238290.jpg
#   inflating: /content/10k_coco/8k_train/000000238449.jpg
#   inflating: /content/10k_coco/8k_train/000000238459.jpg
#  extracting: /content/10k_coco/8k_train/000000238537.jpg
#   inflating: /content/10k_coco/8k_train/000000238584.jpg
#  extracting: /content/10k_coco/8k_train/000000238858.jpg
#  extracting: /content/10k_coco/8k_train/000000238890.jpg
#   inflating: /content/10k_coco/8k_train/000000239120.jpg
#   inflating: /content/10k_coco/8k_train/000000239181.jpg
#   inflating: /content/10k_coco/8k_train/000000239214.jpg
#   inflating: /content/10k_coco/8k_train/000000239492.jpg
#  extracting: /content/10k_coco/8k_train/000000239504.jpg
#  extracting: /content/10k_coco/8k_train/000000239625.jpg
#   inflating: /content/10k_coco/8k_train/000000239671.jpg
#   inflating: /content/10k_coco/8k_train/000000239792.jpg
#   inflating: /content/10k_coco/8k_train/000000239873.jpg
#  extracting: /content/10k_coco/8k_train/000000239936.jpg
#   inflating: /content/10k_coco/8k_train/000000239988.jpg
#   inflating: /content/10k_coco/8k_train/000000240033.jpg
#  extracting: /content/10k_coco/8k_train/000000240057.jpg
#  extracting: /content/10k_coco/8k_train/000000240227.jpg
#   inflating: /content/10k_coco/8k_train/000000240289.jpg
#   inflating: /content/10k_coco/8k_train/000000240329.jpg
#   inflating: /content/10k_coco/8k_train/000000240403.jpg
#  extracting: /content/10k_coco/8k_train/000000240417.jpg
#   inflating: /content/10k_coco/8k_train/000000240423.jpg
#   inflating: /content/10k_coco/8k_train/000000240433.jpg
#   inflating: /content/10k_coco/8k_train/000000240439.jpg
#   inflating: /content/10k_coco/8k_train/000000240495.jpg
#  extracting: /content/10k_coco/8k_train/000000240800.jpg
#   inflating: /content/10k_coco/8k_train/000000240835.jpg
#  extracting: /content/10k_coco/8k_train/000000241170.jpg
#   inflating: /content/10k_coco/8k_train/000000241174.jpg
#  extracting: /content/10k_coco/8k_train/000000241373.jpg
#   inflating: /content/10k_coco/8k_train/000000241503.jpg
#   inflating: /content/10k_coco/8k_train/000000241554.jpg
#  extracting: /content/10k_coco/8k_train/000000241579.jpg
#   inflating: /content/10k_coco/8k_train/000000241667.jpg
#   inflating: /content/10k_coco/8k_train/000000241762.jpg
#   inflating: /content/10k_coco/8k_train/000000241838.jpg
#   inflating: /content/10k_coco/8k_train/000000242001.jpg
#   inflating: /content/10k_coco/8k_train/000000242029.jpg
#   inflating: /content/10k_coco/8k_train/000000242142.jpg
#   inflating: /content/10k_coco/8k_train/000000242169.jpg
#   inflating: /content/10k_coco/8k_train/000000242193.jpg
#   inflating: /content/10k_coco/8k_train/000000242257.jpg
#   inflating: /content/10k_coco/8k_train/000000242307.jpg
#   inflating: /content/10k_coco/8k_train/000000242431.jpg
#   inflating: /content/10k_coco/8k_train/000000242605.jpg
#   inflating: /content/10k_coco/8k_train/000000242664.jpg
#  extracting: /content/10k_coco/8k_train/000000242721.jpg
#   inflating: /content/10k_coco/8k_train/000000242734.jpg
#   inflating: /content/10k_coco/8k_train/000000242821.jpg
#   inflating: /content/10k_coco/8k_train/000000242860.jpg
#   inflating: /content/10k_coco/8k_train/000000243160.jpg
#   inflating: /content/10k_coco/8k_train/000000243214.jpg
#   inflating: /content/10k_coco/8k_train/000000243446.jpg
#   inflating: /content/10k_coco/8k_train/000000243478.jpg
#  extracting: /content/10k_coco/8k_train/000000243491.jpg
#   inflating: /content/10k_coco/8k_train/000000243600.jpg
#   inflating: /content/10k_coco/8k_train/000000243630.jpg
#  extracting: /content/10k_coco/8k_train/000000243734.jpg
#  extracting: /content/10k_coco/8k_train/000000243775.jpg
#   inflating: /content/10k_coco/8k_train/000000243810.jpg
#  extracting: /content/10k_coco/8k_train/000000243847.jpg
#   inflating: /content/10k_coco/8k_train/000000243852.jpg
#   inflating: /content/10k_coco/8k_train/000000243909.jpg
#   inflating: /content/10k_coco/8k_train/000000243910.jpg
#   inflating: /content/10k_coco/8k_train/000000243938.jpg
#   inflating: /content/10k_coco/8k_train/000000243962.jpg
#   inflating: /content/10k_coco/8k_train/000000244011.jpg
#   inflating: /content/10k_coco/8k_train/000000244049.jpg
#   inflating: /content/10k_coco/8k_train/000000244074.jpg
#   inflating: /content/10k_coco/8k_train/000000244095.jpg
#   inflating: /content/10k_coco/8k_train/000000244096.jpg
#  extracting: /content/10k_coco/8k_train/000000244179.jpg
#  extracting: /content/10k_coco/8k_train/000000244215.jpg
#   inflating: /content/10k_coco/8k_train/000000244231.jpg
#  extracting: /content/10k_coco/8k_train/000000244582.jpg
#   inflating: /content/10k_coco/8k_train/000000244589.jpg
#   inflating: /content/10k_coco/8k_train/000000244596.jpg
#   inflating: /content/10k_coco/8k_train/000000244613.jpg
#  extracting: /content/10k_coco/8k_train/000000244616.jpg
#  extracting: /content/10k_coco/8k_train/000000244754.jpg
#   inflating: /content/10k_coco/8k_train/000000244822.jpg
#  extracting: /content/10k_coco/8k_train/000000244836.jpg
#   inflating: /content/10k_coco/8k_train/000000245013.jpg
#   inflating: /content/10k_coco/8k_train/000000245232.jpg
#   inflating: /content/10k_coco/8k_train/000000245298.jpg
#   inflating: /content/10k_coco/8k_train/000000245337.jpg
#   inflating: /content/10k_coco/8k_train/000000245414.jpg
#   inflating: /content/10k_coco/8k_train/000000245425.jpg
#   inflating: /content/10k_coco/8k_train/000000245441.jpg
#   inflating: /content/10k_coco/8k_train/000000245497.jpg
#  extracting: /content/10k_coco/8k_train/000000245559.jpg
#   inflating: /content/10k_coco/8k_train/000000245631.jpg
#   inflating: /content/10k_coco/8k_train/000000245717.jpg
#   inflating: /content/10k_coco/8k_train/000000245754.jpg
#   inflating: /content/10k_coco/8k_train/000000245820.jpg
#   inflating: /content/10k_coco/8k_train/000000245852.jpg
#   inflating: /content/10k_coco/8k_train/000000245853.jpg
#   inflating: /content/10k_coco/8k_train/000000246005.jpg
#  extracting: /content/10k_coco/8k_train/000000246016.jpg
#   inflating: /content/10k_coco/8k_train/000000246081.jpg
#  extracting: /content/10k_coco/8k_train/000000246085.jpg
#  extracting: /content/10k_coco/8k_train/000000246102.jpg
#   inflating: /content/10k_coco/8k_train/000000246231.jpg
#  extracting: /content/10k_coco/8k_train/000000246275.jpg
#   inflating: /content/10k_coco/8k_train/000000246339.jpg
#   inflating: /content/10k_coco/8k_train/000000246356.jpg
#   inflating: /content/10k_coco/8k_train/000000246364.jpg
#   inflating: /content/10k_coco/8k_train/000000246366.jpg
#  extracting: /content/10k_coco/8k_train/000000246456.jpg
#  extracting: /content/10k_coco/8k_train/000000246499.jpg
#   inflating: /content/10k_coco/8k_train/000000246540.jpg
#   inflating: /content/10k_coco/8k_train/000000246597.jpg
#   inflating: /content/10k_coco/8k_train/000000246626.jpg
#   inflating: /content/10k_coco/8k_train/000000246636.jpg
#   inflating: /content/10k_coco/8k_train/000000246649.jpg
#  extracting: /content/10k_coco/8k_train/000000246797.jpg
#   inflating: /content/10k_coco/8k_train/000000246815.jpg
#   inflating: /content/10k_coco/8k_train/000000246875.jpg
#   inflating: /content/10k_coco/8k_train/000000247006.jpg
#  extracting: /content/10k_coco/8k_train/000000247072.jpg
#  extracting: /content/10k_coco/8k_train/000000247285.jpg
#   inflating: /content/10k_coco/8k_train/000000247416.jpg
#  extracting: /content/10k_coco/8k_train/000000247508.jpg
#  extracting: /content/10k_coco/8k_train/000000247529.jpg
#   inflating: /content/10k_coco/8k_train/000000247553.jpg
#   inflating: /content/10k_coco/8k_train/000000247631.jpg
#   inflating: /content/10k_coco/8k_train/000000247692.jpg
#   inflating: /content/10k_coco/8k_train/000000247807.jpg
#   inflating: /content/10k_coco/8k_train/000000247840.jpg
#   inflating: /content/10k_coco/8k_train/000000247858.jpg
#   inflating: /content/10k_coco/8k_train/000000247893.jpg
#   inflating: /content/10k_coco/8k_train/000000248029.jpg
#   inflating: /content/10k_coco/8k_train/000000248051.jpg
#   inflating: /content/10k_coco/8k_train/000000248204.jpg
#  extracting: /content/10k_coco/8k_train/000000248226.jpg
#   inflating: /content/10k_coco/8k_train/000000248229.jpg
#   inflating: /content/10k_coco/8k_train/000000248310.jpg
#   inflating: /content/10k_coco/8k_train/000000248319.jpg
#  extracting: /content/10k_coco/8k_train/000000248324.jpg
#   inflating: /content/10k_coco/8k_train/000000248389.jpg
#  extracting: /content/10k_coco/8k_train/000000248395.jpg
#  extracting: /content/10k_coco/8k_train/000000248461.jpg
#  extracting: /content/10k_coco/8k_train/000000248469.jpg
#   inflating: /content/10k_coco/8k_train/000000248518.jpg
#  extracting: /content/10k_coco/8k_train/000000248694.jpg
#   inflating: /content/10k_coco/8k_train/000000248730.jpg
#   inflating: /content/10k_coco/8k_train/000000248834.jpg
#   inflating: /content/10k_coco/8k_train/000000248945.jpg
#   inflating: /content/10k_coco/8k_train/000000249176.jpg
#   inflating: /content/10k_coco/8k_train/000000249346.jpg
#   inflating: /content/10k_coco/8k_train/000000249348.jpg
#   inflating: /content/10k_coco/8k_train/000000249382.jpg
#  extracting: /content/10k_coco/8k_train/000000249397.jpg
#   inflating: /content/10k_coco/8k_train/000000249441.jpg
#   inflating: /content/10k_coco/8k_train/000000249515.jpg
#   inflating: /content/10k_coco/8k_train/000000249649.jpg
#   inflating: /content/10k_coco/8k_train/000000249670.jpg
#  extracting: /content/10k_coco/8k_train/000000249727.jpg
#   inflating: /content/10k_coco/8k_train/000000250309.jpg
#  extracting: /content/10k_coco/8k_train/000000250313.jpg
#  extracting: /content/10k_coco/8k_train/000000250351.jpg
#   inflating: /content/10k_coco/8k_train/000000250434.jpg
#   inflating: /content/10k_coco/8k_train/000000250474.jpg
#  extracting: /content/10k_coco/8k_train/000000250543.jpg
#   inflating: /content/10k_coco/8k_train/000000250639.jpg
#   inflating: /content/10k_coco/8k_train/000000250778.jpg
#   inflating: /content/10k_coco/8k_train/000000250877.jpg
#  extracting: /content/10k_coco/8k_train/000000250955.jpg
#   inflating: /content/10k_coco/8k_train/000000251036.jpg
#   inflating: /content/10k_coco/8k_train/000000251045.jpg
#  extracting: /content/10k_coco/8k_train/000000251079.jpg
#  extracting: /content/10k_coco/8k_train/000000251094.jpg
#   inflating: /content/10k_coco/8k_train/000000251103.jpg
#  extracting: /content/10k_coco/8k_train/000000251113.jpg
#  extracting: /content/10k_coco/8k_train/000000251183.jpg
#   inflating: /content/10k_coco/8k_train/000000251256.jpg
#   inflating: /content/10k_coco/8k_train/000000251312.jpg
#   inflating: /content/10k_coco/8k_train/000000251330.jpg
#   inflating: /content/10k_coco/8k_train/000000251343.jpg
#   inflating: /content/10k_coco/8k_train/000000251375.jpg
#   inflating: /content/10k_coco/8k_train/000000251379.jpg
#   inflating: /content/10k_coco/8k_train/000000251427.jpg
#  extracting: /content/10k_coco/8k_train/000000251585.jpg
#  extracting: /content/10k_coco/8k_train/000000251626.jpg
#  extracting: /content/10k_coco/8k_train/000000251639.jpg
#   inflating: /content/10k_coco/8k_train/000000251655.jpg
#  extracting: /content/10k_coco/8k_train/000000251690.jpg
#  extracting: /content/10k_coco/8k_train/000000251717.jpg
#   inflating: /content/10k_coco/8k_train/000000251790.jpg
#   inflating: /content/10k_coco/8k_train/000000251897.jpg
#   inflating: /content/10k_coco/8k_train/000000251985.jpg
#  extracting: /content/10k_coco/8k_train/000000251988.jpg
#  extracting: /content/10k_coco/8k_train/000000252008.jpg
#   inflating: /content/10k_coco/8k_train/000000252074.jpg
#   inflating: /content/10k_coco/8k_train/000000252105.jpg
#   inflating: /content/10k_coco/8k_train/000000252144.jpg
#   inflating: /content/10k_coco/8k_train/000000252186.jpg
#  extracting: /content/10k_coco/8k_train/000000252348.jpg
#  extracting: /content/10k_coco/8k_train/000000252383.jpg
#   inflating: /content/10k_coco/8k_train/000000252443.jpg
#   inflating: /content/10k_coco/8k_train/000000252451.jpg
#   inflating: /content/10k_coco/8k_train/000000252581.jpg
#   inflating: /content/10k_coco/8k_train/000000252659.jpg
#  extracting: /content/10k_coco/8k_train/000000252786.jpg
#  extracting: /content/10k_coco/8k_train/000000252807.jpg
#   inflating: /content/10k_coco/8k_train/000000252850.jpg
#  extracting: /content/10k_coco/8k_train/000000252937.jpg
#   inflating: /content/10k_coco/8k_train/000000252970.jpg
#   inflating: /content/10k_coco/8k_train/000000253049.jpg
#  extracting: /content/10k_coco/8k_train/000000253086.jpg
#  extracting: /content/10k_coco/8k_train/000000253125.jpg
#   inflating: /content/10k_coco/8k_train/000000253171.jpg
#  extracting: /content/10k_coco/8k_train/000000253222.jpg
#   inflating: /content/10k_coco/8k_train/000000253290.jpg
#   inflating: /content/10k_coco/8k_train/000000253362.jpg
#  extracting: /content/10k_coco/8k_train/000000253467.jpg
#  extracting: /content/10k_coco/8k_train/000000253532.jpg
#   inflating: /content/10k_coco/8k_train/000000253576.jpg
#   inflating: /content/10k_coco/8k_train/000000253578.jpg
#   inflating: /content/10k_coco/8k_train/000000253579.jpg
#  extracting: /content/10k_coco/8k_train/000000253624.jpg
#   inflating: /content/10k_coco/8k_train/000000253691.jpg
#   inflating: /content/10k_coco/8k_train/000000253764.jpg
#   inflating: /content/10k_coco/8k_train/000000253828.jpg
#   inflating: /content/10k_coco/8k_train/000000253838.jpg
#   inflating: /content/10k_coco/8k_train/000000253873.jpg
#  extracting: /content/10k_coco/8k_train/000000254008.jpg
#  extracting: /content/10k_coco/8k_train/000000254011.jpg
#   inflating: /content/10k_coco/8k_train/000000254100.jpg
#   inflating: /content/10k_coco/8k_train/000000254104.jpg
#   inflating: /content/10k_coco/8k_train/000000254167.jpg
#  extracting: /content/10k_coco/8k_train/000000254191.jpg
#   inflating: /content/10k_coco/8k_train/000000254267.jpg
#   inflating: /content/10k_coco/8k_train/000000254325.jpg
#   inflating: /content/10k_coco/8k_train/000000254414.jpg
#   inflating: /content/10k_coco/8k_train/000000254449.jpg
#   inflating: /content/10k_coco/8k_train/000000254656.jpg
#   inflating: /content/10k_coco/8k_train/000000254712.jpg
#   inflating: /content/10k_coco/8k_train/000000254808.jpg
#   inflating: /content/10k_coco/8k_train/000000254911.jpg
#   inflating: /content/10k_coco/8k_train/000000254930.jpg
#   inflating: /content/10k_coco/8k_train/000000254989.jpg
#   inflating: /content/10k_coco/8k_train/000000255123.jpg
#  extracting: /content/10k_coco/8k_train/000000255448.jpg
#  extracting: /content/10k_coco/8k_train/000000255500.jpg
#   inflating: /content/10k_coco/8k_train/000000255577.jpg
#   inflating: /content/10k_coco/8k_train/000000255604.jpg
#   inflating: /content/10k_coco/8k_train/000000255631.jpg
#   inflating: /content/10k_coco/8k_train/000000255649.jpg
#   inflating: /content/10k_coco/8k_train/000000255654.jpg
#   inflating: /content/10k_coco/8k_train/000000255660.jpg
#  extracting: /content/10k_coco/8k_train/000000255665.jpg
#   inflating: /content/10k_coco/8k_train/000000255682.jpg
#   inflating: /content/10k_coco/8k_train/000000255713.jpg
#   inflating: /content/10k_coco/8k_train/000000255974.jpg
#   inflating: /content/10k_coco/8k_train/000000255999.jpg
#   inflating: /content/10k_coco/8k_train/000000256003.jpg
#  extracting: /content/10k_coco/8k_train/000000256221.jpg
#   inflating: /content/10k_coco/8k_train/000000256222.jpg
#  extracting: /content/10k_coco/8k_train/000000256481.jpg
#   inflating: /content/10k_coco/8k_train/000000256540.jpg
#  extracting: /content/10k_coco/8k_train/000000256589.jpg
#  extracting: /content/10k_coco/8k_train/000000256608.jpg
#   inflating: /content/10k_coco/8k_train/000000256613.jpg
#  extracting: /content/10k_coco/8k_train/000000256734.jpg
#   inflating: /content/10k_coco/8k_train/000000256809.jpg
#  extracting: /content/10k_coco/8k_train/000000256921.jpg
#  extracting: /content/10k_coco/8k_train/000000256946.jpg
#   inflating: /content/10k_coco/8k_train/000000256953.jpg
#  extracting: /content/10k_coco/8k_train/000000257020.jpg
#  extracting: /content/10k_coco/8k_train/000000257178.jpg
#  extracting: /content/10k_coco/8k_train/000000257301.jpg
#   inflating: /content/10k_coco/8k_train/000000257327.jpg
#   inflating: /content/10k_coco/8k_train/000000257341.jpg
#   inflating: /content/10k_coco/8k_train/000000257448.jpg
#  extracting: /content/10k_coco/8k_train/000000257558.jpg
#   inflating: /content/10k_coco/8k_train/000000257628.jpg
#   inflating: /content/10k_coco/8k_train/000000257683.jpg
#   inflating: /content/10k_coco/8k_train/000000257732.jpg
#  extracting: /content/10k_coco/8k_train/000000257791.jpg
#   inflating: /content/10k_coco/8k_train/000000257813.jpg
#  extracting: /content/10k_coco/8k_train/000000257821.jpg
#   inflating: /content/10k_coco/8k_train/000000257838.jpg
#   inflating: /content/10k_coco/8k_train/000000257894.jpg
#   inflating: /content/10k_coco/8k_train/000000257920.jpg
#   inflating: /content/10k_coco/8k_train/000000257946.jpg
#  extracting: /content/10k_coco/8k_train/000000258094.jpg
#   inflating: /content/10k_coco/8k_train/000000258205.jpg
#   inflating: /content/10k_coco/8k_train/000000258344.jpg
#   inflating: /content/10k_coco/8k_train/000000258391.jpg
#   inflating: /content/10k_coco/8k_train/000000258397.jpg
#  extracting: /content/10k_coco/8k_train/000000258414.jpg
#   inflating: /content/10k_coco/8k_train/000000258544.jpg
#   inflating: /content/10k_coco/8k_train/000000258554.jpg
#   inflating: /content/10k_coco/8k_train/000000258559.jpg
#  extracting: /content/10k_coco/8k_train/000000258676.jpg
#  extracting: /content/10k_coco/8k_train/000000258688.jpg
#   inflating: /content/10k_coco/8k_train/000000258738.jpg
#  extracting: /content/10k_coco/8k_train/000000258792.jpg
#   inflating: /content/10k_coco/8k_train/000000258934.jpg
#   inflating: /content/10k_coco/8k_train/000000259067.jpg
#   inflating: /content/10k_coco/8k_train/000000259112.jpg
#  extracting: /content/10k_coco/8k_train/000000259170.jpg
#  extracting: /content/10k_coco/8k_train/000000259232.jpg
#   inflating: /content/10k_coco/8k_train/000000259277.jpg
#   inflating: /content/10k_coco/8k_train/000000259309.jpg
#  extracting: /content/10k_coco/8k_train/000000259422.jpg
#   inflating: /content/10k_coco/8k_train/000000259565.jpg
#  extracting: /content/10k_coco/8k_train/000000259591.jpg
#  extracting: /content/10k_coco/8k_train/000000259594.jpg
#   inflating: /content/10k_coco/8k_train/000000259638.jpg
#  extracting: /content/10k_coco/8k_train/000000259715.jpg
#   inflating: /content/10k_coco/8k_train/000000259719.jpg
#   inflating: /content/10k_coco/8k_train/000000259733.jpg
#   inflating: /content/10k_coco/8k_train/000000259753.jpg
#   inflating: /content/10k_coco/8k_train/000000259817.jpg
#   inflating: /content/10k_coco/8k_train/000000259886.jpg
#   inflating: /content/10k_coco/8k_train/000000259952.jpg
#  extracting: /content/10k_coco/8k_train/000000259959.jpg
#   inflating: /content/10k_coco/8k_train/000000260006.jpg
#   inflating: /content/10k_coco/8k_train/000000260024.jpg
#   inflating: /content/10k_coco/8k_train/000000260034.jpg
#   inflating: /content/10k_coco/8k_train/000000260039.jpg
#   inflating: /content/10k_coco/8k_train/000000260109.jpg
#  extracting: /content/10k_coco/8k_train/000000260150.jpg
#  extracting: /content/10k_coco/8k_train/000000260206.jpg
#   inflating: /content/10k_coco/8k_train/000000260238.jpg
#   inflating: /content/10k_coco/8k_train/000000260307.jpg
#   inflating: /content/10k_coco/8k_train/000000260310.jpg
#   inflating: /content/10k_coco/8k_train/000000260317.jpg
#  extracting: /content/10k_coco/8k_train/000000260398.jpg
#   inflating: /content/10k_coco/8k_train/000000260415.jpg
#   inflating: /content/10k_coco/8k_train/000000260439.jpg
#   inflating: /content/10k_coco/8k_train/000000260566.jpg
#   inflating: /content/10k_coco/8k_train/000000260651.jpg
#   inflating: /content/10k_coco/8k_train/000000260896.jpg
#   inflating: /content/10k_coco/8k_train/000000260910.jpg
#  extracting: /content/10k_coco/8k_train/000000260991.jpg
#   inflating: /content/10k_coco/8k_train/000000261060.jpg
#   inflating: /content/10k_coco/8k_train/000000261266.jpg
#   inflating: /content/10k_coco/8k_train/000000261305.jpg
#   inflating: /content/10k_coco/8k_train/000000261514.jpg
#   inflating: /content/10k_coco/8k_train/000000261520.jpg
#   inflating: /content/10k_coco/8k_train/000000261560.jpg
#  extracting: /content/10k_coco/8k_train/000000261569.jpg
#   inflating: /content/10k_coco/8k_train/000000261603.jpg
#   inflating: /content/10k_coco/8k_train/000000261679.jpg
#   inflating: /content/10k_coco/8k_train/000000261750.jpg
#   inflating: /content/10k_coco/8k_train/000000261945.jpg
#  extracting: /content/10k_coco/8k_train/000000262016.jpg
#  extracting: /content/10k_coco/8k_train/000000262235.jpg
#   inflating: /content/10k_coco/8k_train/000000262325.jpg
#   inflating: /content/10k_coco/8k_train/000000262347.jpg
#  extracting: /content/10k_coco/8k_train/000000262359.jpg
#  extracting: /content/10k_coco/8k_train/000000262391.jpg
#   inflating: /content/10k_coco/8k_train/000000262454.jpg
#  extracting: /content/10k_coco/8k_train/000000262549.jpg
#   inflating: /content/10k_coco/8k_train/000000262550.jpg
#   inflating: /content/10k_coco/8k_train/000000262579.jpg
#  extracting: /content/10k_coco/8k_train/000000262594.jpg
#  extracting: /content/10k_coco/8k_train/000000262724.jpg
#  extracting: /content/10k_coco/8k_train/000000262933.jpg
#  extracting: /content/10k_coco/8k_train/000000262985.jpg
#  extracting: /content/10k_coco/8k_train/000000262986.jpg
#   inflating: /content/10k_coco/8k_train/000000263229.jpg
#   inflating: /content/10k_coco/8k_train/000000263271.jpg
#   inflating: /content/10k_coco/8k_train/000000263288.jpg
#   inflating: /content/10k_coco/8k_train/000000263355.jpg
#   inflating: /content/10k_coco/8k_train/000000263881.jpg
#   inflating: /content/10k_coco/8k_train/000000263901.jpg
#  extracting: /content/10k_coco/8k_train/000000264121.jpg
#   inflating: /content/10k_coco/8k_train/000000264197.jpg
#   inflating: /content/10k_coco/8k_train/000000264201.jpg
#  extracting: /content/10k_coco/8k_train/000000264382.jpg
#   inflating: /content/10k_coco/8k_train/000000264389.jpg
#  extracting: /content/10k_coco/8k_train/000000264495.jpg
#   inflating: /content/10k_coco/8k_train/000000264608.jpg
#  extracting: /content/10k_coco/8k_train/000000264660.jpg
#  extracting: /content/10k_coco/8k_train/000000264712.jpg
#   inflating: /content/10k_coco/8k_train/000000265001.jpg
#  extracting: /content/10k_coco/8k_train/000000265014.jpg
#  extracting: /content/10k_coco/8k_train/000000265023.jpg
#   inflating: /content/10k_coco/8k_train/000000265151.jpg
#   inflating: /content/10k_coco/8k_train/000000265179.jpg
#   inflating: /content/10k_coco/8k_train/000000265186.jpg
#   inflating: /content/10k_coco/8k_train/000000265209.jpg
#  extracting: /content/10k_coco/8k_train/000000265297.jpg
#   inflating: /content/10k_coco/8k_train/000000265351.jpg
#   inflating: /content/10k_coco/8k_train/000000265356.jpg
#   inflating: /content/10k_coco/8k_train/000000265364.jpg
#  extracting: /content/10k_coco/8k_train/000000265536.jpg
#   inflating: /content/10k_coco/8k_train/000000265589.jpg
#  extracting: /content/10k_coco/8k_train/000000265594.jpg
#   inflating: /content/10k_coco/8k_train/000000265629.jpg
#   inflating: /content/10k_coco/8k_train/000000265631.jpg
#  extracting: /content/10k_coco/8k_train/000000265663.jpg
#   inflating: /content/10k_coco/8k_train/000000265701.jpg
#  extracting: /content/10k_coco/8k_train/000000265789.jpg
#   inflating: /content/10k_coco/8k_train/000000265896.jpg
#   inflating: /content/10k_coco/8k_train/000000266114.jpg
#   inflating: /content/10k_coco/8k_train/000000266131.jpg
#   inflating: /content/10k_coco/8k_train/000000266250.jpg
#   inflating: /content/10k_coco/8k_train/000000266350.jpg
#  extracting: /content/10k_coco/8k_train/000000266422.jpg
#   inflating: /content/10k_coco/8k_train/000000266504.jpg
#   inflating: /content/10k_coco/8k_train/000000266517.jpg
#  extracting: /content/10k_coco/8k_train/000000266618.jpg
#   inflating: /content/10k_coco/8k_train/000000266687.jpg
#   inflating: /content/10k_coco/8k_train/000000266749.jpg
#   inflating: /content/10k_coco/8k_train/000000266885.jpg
#   inflating: /content/10k_coco/8k_train/000000266889.jpg
#   inflating: /content/10k_coco/8k_train/000000266912.jpg
#   inflating: /content/10k_coco/8k_train/000000267216.jpg
#   inflating: /content/10k_coco/8k_train/000000267224.jpg
#  extracting: /content/10k_coco/8k_train/000000267266.jpg
#   inflating: /content/10k_coco/8k_train/000000267324.jpg
#   inflating: /content/10k_coco/8k_train/000000267338.jpg
#  extracting: /content/10k_coco/8k_train/000000267502.jpg
#   inflating: /content/10k_coco/8k_train/000000267515.jpg
#   inflating: /content/10k_coco/8k_train/000000267555.jpg
#   inflating: /content/10k_coco/8k_train/000000267556.jpg
#  extracting: /content/10k_coco/8k_train/000000267719.jpg
#   inflating: /content/10k_coco/8k_train/000000267951.jpg
#   inflating: /content/10k_coco/8k_train/000000267998.jpg
#   inflating: /content/10k_coco/8k_train/000000268008.jpg
#   inflating: /content/10k_coco/8k_train/000000268229.jpg
#   inflating: /content/10k_coco/8k_train/000000268340.jpg
#  extracting: /content/10k_coco/8k_train/000000268512.jpg
#   inflating: /content/10k_coco/8k_train/000000268643.jpg
#   inflating: /content/10k_coco/8k_train/000000268726.jpg
#  extracting: /content/10k_coco/8k_train/000000268734.jpg
#   inflating: /content/10k_coco/8k_train/000000268745.jpg
#   inflating: /content/10k_coco/8k_train/000000269017.jpg
#  extracting: /content/10k_coco/8k_train/000000269079.jpg
#  extracting: /content/10k_coco/8k_train/000000269089.jpg
#   inflating: /content/10k_coco/8k_train/000000269338.jpg
#   inflating: /content/10k_coco/8k_train/000000269395.jpg
#  extracting: /content/10k_coco/8k_train/000000269503.jpg
#   inflating: /content/10k_coco/8k_train/000000269532.jpg
#   inflating: /content/10k_coco/8k_train/000000269678.jpg
#  extracting: /content/10k_coco/8k_train/000000269786.jpg
#   inflating: /content/10k_coco/8k_train/000000269903.jpg
#   inflating: /content/10k_coco/8k_train/000000270024.jpg
#   inflating: /content/10k_coco/8k_train/000000270025.jpg
#  extracting: /content/10k_coco/8k_train/000000270070.jpg
#   inflating: /content/10k_coco/8k_train/000000270071.jpg
#   inflating: /content/10k_coco/8k_train/000000270189.jpg
#   inflating: /content/10k_coco/8k_train/000000270275.jpg
#   inflating: /content/10k_coco/8k_train/000000270354.jpg
#   inflating: /content/10k_coco/8k_train/000000270373.jpg
#   inflating: /content/10k_coco/8k_train/000000270603.jpg
#   inflating: /content/10k_coco/8k_train/000000270651.jpg
#   inflating: /content/10k_coco/8k_train/000000270722.jpg
#   inflating: /content/10k_coco/8k_train/000000271106.jpg
#   inflating: /content/10k_coco/8k_train/000000271190.jpg
#   inflating: /content/10k_coco/8k_train/000000271248.jpg
#  extracting: /content/10k_coco/8k_train/000000271283.jpg
#   inflating: /content/10k_coco/8k_train/000000271351.jpg
#   inflating: /content/10k_coco/8k_train/000000271357.jpg
#   inflating: /content/10k_coco/8k_train/000000271396.jpg
#   inflating: /content/10k_coco/8k_train/000000271604.jpg
#  extracting: /content/10k_coco/8k_train/000000271633.jpg
#   inflating: /content/10k_coco/8k_train/000000271842.jpg
#  extracting: /content/10k_coco/8k_train/000000271875.jpg
#  extracting: /content/10k_coco/8k_train/000000271930.jpg
#   inflating: /content/10k_coco/8k_train/000000271960.jpg
#  extracting: /content/10k_coco/8k_train/000000271996.jpg
#   inflating: /content/10k_coco/8k_train/000000272153.jpg
#  extracting: /content/10k_coco/8k_train/000000272173.jpg
#  extracting: /content/10k_coco/8k_train/000000272188.jpg
#   inflating: /content/10k_coco/8k_train/000000272343.jpg
#   inflating: /content/10k_coco/8k_train/000000272420.jpg
#   inflating: /content/10k_coco/8k_train/000000272615.jpg
#   inflating: /content/10k_coco/8k_train/000000272658.jpg
#   inflating: /content/10k_coco/8k_train/000000272743.jpg
#   inflating: /content/10k_coco/8k_train/000000272758.jpg
#   inflating: /content/10k_coco/8k_train/000000272852.jpg
#   inflating: /content/10k_coco/8k_train/000000272859.jpg
#  extracting: /content/10k_coco/8k_train/000000273045.jpg
#   inflating: /content/10k_coco/8k_train/000000273088.jpg
#   inflating: /content/10k_coco/8k_train/000000273089.jpg
#  extracting: /content/10k_coco/8k_train/000000273119.jpg
#   inflating: /content/10k_coco/8k_train/000000273207.jpg
#   inflating: /content/10k_coco/8k_train/000000273352.jpg
#  extracting: /content/10k_coco/8k_train/000000273421.jpg
#   inflating: /content/10k_coco/8k_train/000000273591.jpg
#   inflating: /content/10k_coco/8k_train/000000273650.jpg
#  extracting: /content/10k_coco/8k_train/000000273653.jpg
#   inflating: /content/10k_coco/8k_train/000000273708.jpg
#   inflating: /content/10k_coco/8k_train/000000273840.jpg
#  extracting: /content/10k_coco/8k_train/000000273874.jpg
#  extracting: /content/10k_coco/8k_train/000000273929.jpg
#  extracting: /content/10k_coco/8k_train/000000274054.jpg
#   inflating: /content/10k_coco/8k_train/000000274079.jpg
#   inflating: /content/10k_coco/8k_train/000000274084.jpg
#  extracting: /content/10k_coco/8k_train/000000274105.jpg
#  extracting: /content/10k_coco/8k_train/000000274130.jpg
#   inflating: /content/10k_coco/8k_train/000000274209.jpg
#   inflating: /content/10k_coco/8k_train/000000274270.jpg
#   inflating: /content/10k_coco/8k_train/000000274323.jpg
#  extracting: /content/10k_coco/8k_train/000000274424.jpg
#   inflating: /content/10k_coco/8k_train/000000274477.jpg
#   inflating: /content/10k_coco/8k_train/000000274536.jpg
#   inflating: /content/10k_coco/8k_train/000000274547.jpg
#   inflating: /content/10k_coco/8k_train/000000274632.jpg
#  extracting: /content/10k_coco/8k_train/000000274888.jpg
#   inflating: /content/10k_coco/8k_train/000000274907.jpg
#   inflating: /content/10k_coco/8k_train/000000274917.jpg
#   inflating: /content/10k_coco/8k_train/000000274977.jpg
#  extracting: /content/10k_coco/8k_train/000000275028.jpg
#   inflating: /content/10k_coco/8k_train/000000275115.jpg
#  extracting: /content/10k_coco/8k_train/000000275120.jpg
#  extracting: /content/10k_coco/8k_train/000000275175.jpg
#   inflating: /content/10k_coco/8k_train/000000275210.jpg
#   inflating: /content/10k_coco/8k_train/000000275253.jpg
#   inflating: /content/10k_coco/8k_train/000000275316.jpg
#   inflating: /content/10k_coco/8k_train/000000275332.jpg
#  extracting: /content/10k_coco/8k_train/000000275374.jpg
#   inflating: /content/10k_coco/8k_train/000000275532.jpg
#   inflating: /content/10k_coco/8k_train/000000275544.jpg
#   inflating: /content/10k_coco/8k_train/000000275556.jpg
#   inflating: /content/10k_coco/8k_train/000000275604.jpg
#   inflating: /content/10k_coco/8k_train/000000275612.jpg
#   inflating: /content/10k_coco/8k_train/000000275643.jpg
#   inflating: /content/10k_coco/8k_train/000000275656.jpg
#  extracting: /content/10k_coco/8k_train/000000275843.jpg
#   inflating: /content/10k_coco/8k_train/000000275850.jpg
#   inflating: /content/10k_coco/8k_train/000000275869.jpg
#   inflating: /content/10k_coco/8k_train/000000275930.jpg
#   inflating: /content/10k_coco/8k_train/000000275969.jpg
#   inflating: /content/10k_coco/8k_train/000000275988.jpg
#   inflating: /content/10k_coco/8k_train/000000276047.jpg
#  extracting: /content/10k_coco/8k_train/000000276062.jpg
#   inflating: /content/10k_coco/8k_train/000000276354.jpg
#   inflating: /content/10k_coco/8k_train/000000276365.jpg
#   inflating: /content/10k_coco/8k_train/000000276479.jpg
#   inflating: /content/10k_coco/8k_train/000000276514.jpg
#   inflating: /content/10k_coco/8k_train/000000276528.jpg
#  extracting: /content/10k_coco/8k_train/000000276719.jpg
#   inflating: /content/10k_coco/8k_train/000000276845.jpg
#   inflating: /content/10k_coco/8k_train/000000276870.jpg
#  extracting: /content/10k_coco/8k_train/000000276874.jpg
#  extracting: /content/10k_coco/8k_train/000000276918.jpg
#   inflating: /content/10k_coco/8k_train/000000276956.jpg
#   inflating: /content/10k_coco/8k_train/000000277032.jpg
#  extracting: /content/10k_coco/8k_train/000000277070.jpg
#   inflating: /content/10k_coco/8k_train/000000277161.jpg
#   inflating: /content/10k_coco/8k_train/000000277165.jpg
#   inflating: /content/10k_coco/8k_train/000000277284.jpg
#   inflating: /content/10k_coco/8k_train/000000277341.jpg
#   inflating: /content/10k_coco/8k_train/000000277383.jpg
#   inflating: /content/10k_coco/8k_train/000000277403.jpg
#  extracting: /content/10k_coco/8k_train/000000277481.jpg
#  extracting: /content/10k_coco/8k_train/000000277637.jpg
#   inflating: /content/10k_coco/8k_train/000000277665.jpg
#  extracting: /content/10k_coco/8k_train/000000277694.jpg
#   inflating: /content/10k_coco/8k_train/000000277793.jpg
#   inflating: /content/10k_coco/8k_train/000000277918.jpg
#  extracting: /content/10k_coco/8k_train/000000278043.jpg
#   inflating: /content/10k_coco/8k_train/000000278055.jpg
#   inflating: /content/10k_coco/8k_train/000000278204.jpg
#   inflating: /content/10k_coco/8k_train/000000278222.jpg
#  extracting: /content/10k_coco/8k_train/000000278243.jpg
#   inflating: /content/10k_coco/8k_train/000000278309.jpg
#   inflating: /content/10k_coco/8k_train/000000278555.jpg
#   inflating: /content/10k_coco/8k_train/000000278627.jpg
#   inflating: /content/10k_coco/8k_train/000000278638.jpg
#   inflating: /content/10k_coco/8k_train/000000278747.jpg
#   inflating: /content/10k_coco/8k_train/000000278776.jpg
#   inflating: /content/10k_coco/8k_train/000000278829.jpg
#   inflating: /content/10k_coco/8k_train/000000278922.jpg
# ...
#   inflating: /content/10k_coco/8k_train/000000562171.jpg
#   inflating: /content/10k_coco/8k_train/000000562398.jpg
#  extracting: /content/10k_coco/8k_train/000000562474.jpg
#   inflating: /content/10k_coco/8k_train/000000562557.jpg
#   inflating: /content/10k_coco/8k_train/000000562574.jpg
#   inflating: /content/10k_coco/8k_train/000000562623.jpg
#   inflating: /content/10k_coco/8k_train/000000562664.jpg
#   inflating: /content/10k_coco/8k_train/000000562675.jpg
#   inflating: /content/10k_coco/8k_train/000000562778.jpg
#   inflating: /content/10k_coco/8k_train/000000562803.jpg
#  extracting: /content/10k_coco/8k_train/000000562861.jpg
#   inflating: /content/10k_coco/8k_train/000000562879.jpg
#  extracting: /content/10k_coco/8k_train/000000562999.jpg
#   inflating: /content/10k_coco/8k_train/000000563053.jpg
#   inflating: /content/10k_coco/8k_train/000000563058.jpg
#  extracting: /content/10k_coco/8k_train/000000563070.jpg
#   inflating: /content/10k_coco/8k_train/000000563264.jpg
#  extracting: /content/10k_coco/8k_train/000000563340.jpg
#   inflating: /content/10k_coco/8k_train/000000563371.jpg
#   inflating: /content/10k_coco/8k_train/000000563376.jpg
#   inflating: /content/10k_coco/8k_train/000000563381.jpg
#   inflating: /content/10k_coco/8k_train/000000563511.jpg
#   inflating: /content/10k_coco/8k_train/000000563525.jpg
#   inflating: /content/10k_coco/8k_train/000000563655.jpg
#  extracting: /content/10k_coco/8k_train/000000563659.jpg
#  extracting: /content/10k_coco/8k_train/000000563665.jpg
#   inflating: /content/10k_coco/8k_train/000000563731.jpg
#   inflating: /content/10k_coco/8k_train/000000563803.jpg
#   inflating: /content/10k_coco/8k_train/000000563817.jpg
#   inflating: /content/10k_coco/8k_train/000000563858.jpg
#   inflating: /content/10k_coco/8k_train/000000563945.jpg
#   inflating: /content/10k_coco/8k_train/000000564031.jpg
#   inflating: /content/10k_coco/8k_train/000000564153.jpg
#  extracting: /content/10k_coco/8k_train/000000564185.jpg
#   inflating: /content/10k_coco/8k_train/000000564198.jpg
#   inflating: /content/10k_coco/8k_train/000000564287.jpg
#  extracting: /content/10k_coco/8k_train/000000564352.jpg
#   inflating: /content/10k_coco/8k_train/000000564515.jpg
#   inflating: /content/10k_coco/8k_train/000000564557.jpg
#   inflating: /content/10k_coco/8k_train/000000564596.jpg
#   inflating: /content/10k_coco/8k_train/000000564659.jpg
#   inflating: /content/10k_coco/8k_train/000000564663.jpg
#   inflating: /content/10k_coco/8k_train/000000564676.jpg
#  extracting: /content/10k_coco/8k_train/000000564796.jpg
#   inflating: /content/10k_coco/8k_train/000000564978.jpg
#   inflating: /content/10k_coco/8k_train/000000565041.jpg
#   inflating: /content/10k_coco/8k_train/000000565109.jpg
#   inflating: /content/10k_coco/8k_train/000000565115.jpg
#   inflating: /content/10k_coco/8k_train/000000565165.jpg
#   inflating: /content/10k_coco/8k_train/000000565230.jpg
#  extracting: /content/10k_coco/8k_train/000000565235.jpg
#   inflating: /content/10k_coco/8k_train/000000565243.jpg
#  extracting: /content/10k_coco/8k_train/000000565273.jpg
#   inflating: /content/10k_coco/8k_train/000000565326.jpg
#   inflating: /content/10k_coco/8k_train/000000565353.jpg
#   inflating: /content/10k_coco/8k_train/000000565797.jpg
#   inflating: /content/10k_coco/8k_train/000000565957.jpg
#   inflating: /content/10k_coco/8k_train/000000566038.jpg
#   inflating: /content/10k_coco/8k_train/000000566051.jpg
#   inflating: /content/10k_coco/8k_train/000000566135.jpg
#   inflating: /content/10k_coco/8k_train/000000566201.jpg
#   inflating: /content/10k_coco/8k_train/000000566261.jpg
#   inflating: /content/10k_coco/8k_train/000000566501.jpg
#  extracting: /content/10k_coco/8k_train/000000566646.jpg
#  extracting: /content/10k_coco/8k_train/000000566700.jpg
#   inflating: /content/10k_coco/8k_train/000000566729.jpg
#   inflating: /content/10k_coco/8k_train/000000566756.jpg
#   inflating: /content/10k_coco/8k_train/000000566757.jpg
#  extracting: /content/10k_coco/8k_train/000000566837.jpg
#   inflating: /content/10k_coco/8k_train/000000566855.jpg
#  extracting: /content/10k_coco/8k_train/000000566955.jpg
#   inflating: /content/10k_coco/8k_train/000000566998.jpg
#   inflating: /content/10k_coco/8k_train/000000567057.jpg
#   inflating: /content/10k_coco/8k_train/000000567121.jpg
#   inflating: /content/10k_coco/8k_train/000000567276.jpg
#  extracting: /content/10k_coco/8k_train/000000567304.jpg
#  extracting: /content/10k_coco/8k_train/000000567305.jpg
#  extracting: /content/10k_coco/8k_train/000000567315.jpg
#   inflating: /content/10k_coco/8k_train/000000567403.jpg
#   inflating: /content/10k_coco/8k_train/000000567727.jpg
#   inflating: /content/10k_coco/8k_train/000000567797.jpg
#   inflating: /content/10k_coco/8k_train/000000567850.jpg
#   inflating: /content/10k_coco/8k_train/000000568089.jpg
#  extracting: /content/10k_coco/8k_train/000000568148.jpg
#  extracting: /content/10k_coco/8k_train/000000568202.jpg
#   inflating: /content/10k_coco/8k_train/000000568243.jpg
#   inflating: /content/10k_coco/8k_train/000000568357.jpg
#  extracting: /content/10k_coco/8k_train/000000568455.jpg
#   inflating: /content/10k_coco/8k_train/000000568471.jpg
#   inflating: /content/10k_coco/8k_train/000000568516.jpg
#   inflating: /content/10k_coco/8k_train/000000568611.jpg
#   inflating: /content/10k_coco/8k_train/000000568623.jpg
#  extracting: /content/10k_coco/8k_train/000000568725.jpg
#   inflating: /content/10k_coco/8k_train/000000568790.jpg
#   inflating: /content/10k_coco/8k_train/000000568879.jpg
#   inflating: /content/10k_coco/8k_train/000000568893.jpg
#   inflating: /content/10k_coco/8k_train/000000569069.jpg
#   inflating: /content/10k_coco/8k_train/000000569075.jpg
#  extracting: /content/10k_coco/8k_train/000000569190.jpg
#   inflating: /content/10k_coco/8k_train/000000569205.jpg
#   inflating: /content/10k_coco/8k_train/000000569249.jpg
#   inflating: /content/10k_coco/8k_train/000000569250.jpg
#   inflating: /content/10k_coco/8k_train/000000569255.jpg
#   inflating: /content/10k_coco/8k_train/000000569389.jpg
#  extracting: /content/10k_coco/8k_train/000000569414.jpg
#   inflating: /content/10k_coco/8k_train/000000569536.jpg
#   inflating: /content/10k_coco/8k_train/000000569582.jpg
#   inflating: /content/10k_coco/8k_train/000000569597.jpg
#  extracting: /content/10k_coco/8k_train/000000569683.jpg
#   inflating: /content/10k_coco/8k_train/000000569706.jpg
#   inflating: /content/10k_coco/8k_train/000000569718.jpg
#   inflating: /content/10k_coco/8k_train/000000569969.jpg
#   inflating: /content/10k_coco/8k_train/000000570060.jpg
#  extracting: /content/10k_coco/8k_train/000000570211.jpg
#   inflating: /content/10k_coco/8k_train/000000570280.jpg
#   inflating: /content/10k_coco/8k_train/000000570339.jpg
#   inflating: /content/10k_coco/8k_train/000000570392.jpg
#   inflating: /content/10k_coco/8k_train/000000570460.jpg
#   inflating: /content/10k_coco/8k_train/000000570781.jpg
#   inflating: /content/10k_coco/8k_train/000000570801.jpg
#   inflating: /content/10k_coco/8k_train/000000570807.jpg
#   inflating: /content/10k_coco/8k_train/000000570822.jpg
#   inflating: /content/10k_coco/8k_train/000000570945.jpg
#   inflating: /content/10k_coco/8k_train/000000571125.jpg
#   inflating: /content/10k_coco/8k_train/000000571357.jpg
#   inflating: /content/10k_coco/8k_train/000000571396.jpg
#   inflating: /content/10k_coco/8k_train/000000571596.jpg
#   inflating: /content/10k_coco/8k_train/000000571638.jpg
#   inflating: /content/10k_coco/8k_train/000000571648.jpg
#   inflating: /content/10k_coco/8k_train/000000571787.jpg
#   inflating: /content/10k_coco/8k_train/000000571821.jpg
#   inflating: /content/10k_coco/8k_train/000000571996.jpg
#  extracting: /content/10k_coco/8k_train/000000572084.jpg
#   inflating: /content/10k_coco/8k_train/000000572210.jpg
#   inflating: /content/10k_coco/8k_train/000000572326.jpg
#   inflating: /content/10k_coco/8k_train/000000572383.jpg
#  extracting: /content/10k_coco/8k_train/000000572554.jpg
#   inflating: /content/10k_coco/8k_train/000000572602.jpg
#   inflating: /content/10k_coco/8k_train/000000572615.jpg
#   inflating: /content/10k_coco/8k_train/000000572627.jpg
#  extracting: /content/10k_coco/8k_train/000000572801.jpg
#  extracting: /content/10k_coco/8k_train/000000572814.jpg
#  extracting: /content/10k_coco/8k_train/000000572840.jpg
#   inflating: /content/10k_coco/8k_train/000000572861.jpg
#  extracting: /content/10k_coco/8k_train/000000573085.jpg
#  extracting: /content/10k_coco/8k_train/000000573107.jpg
#   inflating: /content/10k_coco/8k_train/000000573119.jpg
#   inflating: /content/10k_coco/8k_train/000000573146.jpg
#   inflating: /content/10k_coco/8k_train/000000573388.jpg
#   inflating: /content/10k_coco/8k_train/000000573430.jpg
#   inflating: /content/10k_coco/8k_train/000000573565.jpg
#  extracting: /content/10k_coco/8k_train/000000573605.jpg
#   inflating: /content/10k_coco/8k_train/000000573843.jpg
#   inflating: /content/10k_coco/8k_train/000000573922.jpg
#   inflating: /content/10k_coco/8k_train/000000573924.jpg
#   inflating: /content/10k_coco/8k_train/000000573935.jpg
#  extracting: /content/10k_coco/8k_train/000000573941.jpg
#  extracting: /content/10k_coco/8k_train/000000573954.jpg
#  extracting: /content/10k_coco/8k_train/000000573988.jpg
#  extracting: /content/10k_coco/8k_train/000000574063.jpg
#   inflating: /content/10k_coco/8k_train/000000574103.jpg
#   inflating: /content/10k_coco/8k_train/000000574110.jpg
#   inflating: /content/10k_coco/8k_train/000000574145.jpg
#   inflating: /content/10k_coco/8k_train/000000574463.jpg
#  extracting: /content/10k_coco/8k_train/000000574675.jpg
#  extracting: /content/10k_coco/8k_train/000000574769.jpg
#   inflating: /content/10k_coco/8k_train/000000574928.jpg
#  extracting: /content/10k_coco/8k_train/000000574955.jpg
#   inflating: /content/10k_coco/8k_train/000000574957.jpg
#   inflating: /content/10k_coco/8k_train/000000575008.jpg
#   inflating: /content/10k_coco/8k_train/000000575027.jpg
#   inflating: /content/10k_coco/8k_train/000000575040.jpg
#   inflating: /content/10k_coco/8k_train/000000575052.jpg
#   inflating: /content/10k_coco/8k_train/000000575119.jpg
#   inflating: /content/10k_coco/8k_train/000000575209.jpg
#   inflating: /content/10k_coco/8k_train/000000575287.jpg
#   inflating: /content/10k_coco/8k_train/000000575319.jpg
#   inflating: /content/10k_coco/8k_train/000000575323.jpg
#   inflating: /content/10k_coco/8k_train/000000575354.jpg
#   inflating: /content/10k_coco/8k_train/000000575356.jpg
#  extracting: /content/10k_coco/8k_train/000000575361.jpg
#  extracting: /content/10k_coco/8k_train/000000575406.jpg
#   inflating: /content/10k_coco/8k_train/000000575441.jpg
#  extracting: /content/10k_coco/8k_train/000000575612.jpg
#   inflating: /content/10k_coco/8k_train/000000575628.jpg
#   inflating: /content/10k_coco/8k_train/000000575637.jpg
#   inflating: /content/10k_coco/8k_train/000000575641.jpg
#  extracting: /content/10k_coco/8k_train/000000575652.jpg
#   inflating: /content/10k_coco/8k_train/000000575772.jpg
#   inflating: /content/10k_coco/8k_train/000000575867.jpg
#   inflating: /content/10k_coco/8k_train/000000575946.jpg
#   inflating: /content/10k_coco/8k_train/000000576030.jpg
#   inflating: /content/10k_coco/8k_train/000000576040.jpg
#   inflating: /content/10k_coco/8k_train/000000576075.jpg
#   inflating: /content/10k_coco/8k_train/000000576160.jpg
#  extracting: /content/10k_coco/8k_train/000000576222.jpg
#   inflating: /content/10k_coco/8k_train/000000576301.jpg
#   inflating: /content/10k_coco/8k_train/000000576305.jpg
#   inflating: /content/10k_coco/8k_train/000000576376.jpg
#   inflating: /content/10k_coco/8k_train/000000576445.jpg
#  extracting: /content/10k_coco/8k_train/000000576612.jpg
#  extracting: /content/10k_coco/8k_train/000000576675.jpg
#   inflating: /content/10k_coco/8k_train/000000576733.jpg
#   inflating: /content/10k_coco/8k_train/000000576749.jpg
#  extracting: /content/10k_coco/8k_train/000000576780.jpg
#   inflating: /content/10k_coco/8k_train/000000576875.jpg
#  extracting: /content/10k_coco/8k_train/000000577036.jpg
#  extracting: /content/10k_coco/8k_train/000000577079.jpg
#   inflating: /content/10k_coco/8k_train/000000577129.jpg
#   inflating: /content/10k_coco/8k_train/000000577321.jpg
#   inflating: /content/10k_coco/8k_train/000000577355.jpg
#   inflating: /content/10k_coco/8k_train/000000577411.jpg
#   inflating: /content/10k_coco/8k_train/000000577717.jpg
#  extracting: /content/10k_coco/8k_train/000000577725.jpg
#  extracting: /content/10k_coco/8k_train/000000577838.jpg
#   inflating: /content/10k_coco/8k_train/000000577891.jpg
#   inflating: /content/10k_coco/8k_train/000000578046.jpg
#  extracting: /content/10k_coco/8k_train/000000578092.jpg
#   inflating: /content/10k_coco/8k_train/000000578108.jpg
#   inflating: /content/10k_coco/8k_train/000000578128.jpg
#   inflating: /content/10k_coco/8k_train/000000578131.jpg
#   inflating: /content/10k_coco/8k_train/000000578227.jpg
#   inflating: /content/10k_coco/8k_train/000000578292.jpg
#   inflating: /content/10k_coco/8k_train/000000578331.jpg
#   inflating: /content/10k_coco/8k_train/000000578482.jpg
#  extracting: /content/10k_coco/8k_train/000000578671.jpg
#   inflating: /content/10k_coco/8k_train/000000578765.jpg
#   inflating: /content/10k_coco/8k_train/000000578856.jpg
#   inflating: /content/10k_coco/8k_train/000000578961.jpg
#  extracting: /content/10k_coco/8k_train/000000579000.jpg
#  extracting: /content/10k_coco/8k_train/000000579003.jpg
#   inflating: /content/10k_coco/8k_train/000000579056.jpg
#   inflating: /content/10k_coco/8k_train/000000579057.jpg
#   inflating: /content/10k_coco/8k_train/000000579060.jpg
#   inflating: /content/10k_coco/8k_train/000000579145.jpg
#   inflating: /content/10k_coco/8k_train/000000579224.jpg
#   inflating: /content/10k_coco/8k_train/000000579231.jpg
#   inflating: /content/10k_coco/8k_train/000000579267.jpg
#   inflating: /content/10k_coco/8k_train/000000579462.jpg
#   inflating: /content/10k_coco/8k_train/000000579491.jpg
#   inflating: /content/10k_coco/8k_train/000000579713.jpg
#   inflating: /content/10k_coco/8k_train/000000579813.jpg
#   inflating: /content/10k_coco/8k_train/000000579814.jpg
#   inflating: /content/10k_coco/8k_train/000000579918.jpg
#   inflating: /content/10k_coco/8k_train/000000580052.jpg
#   inflating: /content/10k_coco/8k_train/000000580255.jpg
#  extracting: /content/10k_coco/8k_train/000000580813.jpg
#   inflating: /content/10k_coco/8k_train/000000580887.jpg
#  extracting: /content/10k_coco/8k_train/000000580913.jpg
#   inflating: /content/10k_coco/8k_train/000000580957.jpg
#   inflating: /content/10k_coco/8k_train/000000581022.jpg
#   inflating: /content/10k_coco/8k_train/000000581081.jpg
#  extracting: /content/10k_coco/8k_train/000000581089.jpg
#   inflating: /content/10k_coco/8k_train/000000581118.jpg
#   inflating: /content/10k_coco/8k_train/000000581181.jpg
#   inflating: /content/10k_coco/8k_train/000000581233.jpg
#   inflating: /content/10k_coco/8k_train/000000581282.jpg
#   inflating: /content/10k_coco/8k_train/000000581297.jpg
#   inflating: /content/10k_coco/8k_train/000000581338.jpg
#   inflating: /content/10k_coco/8k_train/000000581394.jpg
#  extracting: /content/10k_coco/8k_train/000000581481.jpg
#  extracting: /content/10k_coco/8k_train/000000581486.jpg
#  extracting: /content/10k_coco/8k_train/000000581557.jpg
#   inflating: /content/10k_coco/8k_train/000000581566.jpg
#   inflating: /content/10k_coco/8k_train/000000581601.jpg
#   inflating: /content/10k_coco/8k_train/000000581668.jpg
#  extracting: /content/10k_coco/8k_train/000000581702.jpg
#  extracting: /content/10k_coco/8k_train/000000581736.jpg
#  extracting: /content/10k_coco/8k_train/000000581881.jpg
#   inflating: /content/10k_coco/test_20.json
#   inflating: /content/10k_coco/train_80.json

# %%
# train_dir = os.path.join(BASE_PATH, 'data/10k_coco/images')
# ann_dir = os.path.join(BASE_PATH, 'data/10k_coco/train_80.json')
train_dir = os.path.join('/content/10k_coco/8k_train')
ann_dir = os.path.join('/content/10k_coco/train_80.json')

dataset = COCODataset(train_dir,
                      ann_dir,
                      args.targetHeight,
                      args.targetWidth,
                      args.numClass)
dataloader = DataLoader(dataset,
                        batch_size=args.batchSize,
                        shuffle=False,
                        collate_fn=collateFunction,
                        pin_memory=True,
                        num_workers=args.numWorkers)
# Out:
# loading annotations into memory...
# Done (t=1.28s)
# creating index...
# index created!

# %%
model = DETR(args).to(device)
criterion = SetCriterion(args).to(device)

# %%
# if args.weightDir and os.path.exists(args.weightDir):
#     print(f'loading pre-trained weights from {args.weightDir}')
#     model.load_state_dict(torch.load(args.weightDir, map_location=device))

# multi-GPU training
if args.multi:
    model = torch.nn.DataParallel(model)
        
# separate learning rate     
paramDicts = [
        {"params": [p for n, p in model.named_parameters() if "backbone" not in n and p.requires_grad]},
        {
            "params": [p for n, p in model.named_parameters() if "backbone" in n and p.requires_grad],
            "lr": args.lrBackbone,
        },
    ]

# %%
start_epoch = 0
optimizer = AdamW(paramDicts, args.lr, weight_decay=args.weightDecay)
lr_scheduler = StepLR(optimizer, args.lrDrop)
prev_best_loss = np.inf
batches = len(dataloader)
logger = MetricsLogger()

# !pip install -U pytorch_warmup
# import pytorch_warmup as warmup
# warmup_scheduler = warmup.RAdamWarmup(optimizer)

# %% [markdown]
# ## Resume training

# %%
# args.outputDir = '/content/drive/My Drive/jupyter/results/detr_200_16bs'

# %%
CHECKPOINT_PATH = "/content/drive/My Drive/jupyter/results/detr_200_8bs"

# %%
args.datasetType
# Out:
# '10k_coco'

# %%
assert os.path.isdir(CHECKPOINT_PATH)
checkpoint = torch.load(f'{CHECKPOINT_PATH}/{args.datasetType}.pt')
model.load_state_dict(checkpoint['model'])
prev_best_loss = checkpoint['loss']
start_epoch = checkpoint['epoch']
print(f'loss is: {prev_best_loss}, start from: {start_epoch}')
# Out:
# loss is: 31.71209770482207, start from: 73

# %%
losses = []
def train(epoch, prev_best_loss):
    model.train()
    criterion.train()
    scaler = amp.GradScaler()
    with tqdm(dataloader, unit='batch') as tepoch:
        for (x, y) in tepoch:
            tepoch.set_description(f'Train epoch {epoch}')
            
            x = x.to(device)
            y = [{k: v.to(device) for k, v in t.items()} for t in y]

            if args.amp:
                with amp.autocast():
                    out = model(x)
                out = cast2Float(out)
            else:
                out = model(x)

            metrics = criterion(out, y)
            
            loss = sum(v for k, v in metrics.items() if 'loss' in k)
            losses.append(loss.cpu().item())

            # MARK: - backpropagation
            optimizer.zero_grad()
            if args.amp:
                scaler.scale(loss).backward()
                if args.clipMaxNorm > 0:
                    scaler.unscale_(optimizer)
                    torch.nn.utils.clip_grad_norm_(model.parameters(), args.clipMaxNorm)
                scaler.step(optimizer)
                scaler.update()
            else:
                loss.backward()
                if args.clipMaxNorm > 0:
                    torch.nn.utils.clip_grad_norm_(model.parameters(), args.clipMaxNorm)
                optimizer.step()
            tepoch.set_postfix(loss=loss.cpu().item()) 
            
        lr_scheduler.step()
        # warmup_scheduler.dampen()

        print(lr_scheduler.get_last_lr())
        avg_loss = np.mean(losses)

        if avg_loss < prev_best_loss:
            print('[+] Loss improved from {:.8f} to {:.8f}, saving model...'.format(prev_best_loss,
                                                                                    avg_loss))
            
            if not os.path.exists(args.outputDir):
                os.mkdir(args.outputDir)

            try:
                state = {
                'model': model.state_dict(),
                'optimizer': optimizer.state_dict(),
                'lr_scheduler': lr_scheduler.state_dict(),
                'loss': prev_best_loss,
                'epoch': epoch
                }
            except AttributeError:
                pass
            torch.save(state, f'{args.outputDir}/{args.datasetType}.pt')
            prev_best_loss = avg_loss
        
        with open(f'{args.outputDir}/losses.txt', 'a') as fd:
          fd.write(f'{avg_loss}\n')

        return prev_best_loss
        
        # Plots    
#         if epoch < 3:
#             f = f'{args.project}/train_batch{epoch}.jpg'
#             Thread(target=plot_images, args=(x, y, None, f), daemon=True).start()

# %%
for epoch in trange(start_epoch, start_epoch+args.epochs):
    prev_best_loss = train(epoch, prev_best_loss)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=200.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 31.71209770 to 30.99506278, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.99506278 to 30.95868158, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.95868158 to 30.93418217, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.93418217 to 30.92615123, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.92615123 to 30.91461314, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.91461314 to 30.89850374, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.89850374 to 30.88767288, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.88767288 to 30.87419733, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.87419733 to 30.86174114, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.86174114 to 30.85049901, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.85049901 to 30.84278806, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.84278806 to 30.83500452, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.83500452 to 30.82733667, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.82733667 to 30.81900616, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.81900616 to 30.81110931, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.81110931 to 30.80317718, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.80317718 to 30.79613237, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.79613237 to 30.78939235, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.78939235 to 30.78083675, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.78083675 to 30.77161002, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.77161002 to 30.76265360, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.76265360 to 30.75430357, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.75430357 to 30.74759509, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.74759509 to 30.74169515, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.74169515 to 30.73602304, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.73602304 to 30.73110538, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.73110538 to 30.72576401, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.72576401 to 30.72090305, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.72090305 to 30.71453122, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.71453122 to 30.70833421, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.70833421 to 30.70248780, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.70248780 to 30.69720467, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.69720467 to 30.69310839, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.69310839 to 30.68840449, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.68840449 to 30.68375236, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.68375236 to 30.67947789, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.67947789 to 30.67481789, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.67481789 to 30.67003018, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.67003018 to 30.66622731, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.66622731 to 30.66163551, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.66163551 to 30.65668804, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.65668804 to 30.65220349, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.65220349 to 30.64764190, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.64764190 to 30.64366659, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.64366659 to 30.64019003, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.64019003 to 30.63621003, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.63621003 to 30.63235567, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.63235567 to 30.62919913, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.62919913 to 30.62596041, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.62596041 to 30.62376584, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.62376584 to 30.62217094, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.62217094 to 30.61969299, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.61969299 to 30.61846717, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.61846717 to 30.61625270, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.61625270 to 30.61474250, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.61474250 to 30.61306081, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.61306081 to 30.61048617, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.61048617 to 30.60813544, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.60813544 to 30.60536238, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.60536238 to 30.60347926, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.60347926 to 30.60129025, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.60129025 to 30.60024220, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# [+] Loss improved from 30.60024220 to 30.59845067, saving model...
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# [0.0001, 1e-05]
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-627a68a20065> in <module>()
#       1 for epoch in trange(start_epoch, start_epoch+args.epochs):
# ----> 2     prev_best_loss = train(epoch, prev_best_loss)
#
# <ipython-input-22-84a2c24946cc> in train(epoch, prev_best_loss)
#      18                 out = model(x)
#      19
# ---> 20             metrics = criterion(out, y)
#      21
#      22             loss = sum(v for k, v in metrics.items() if 'loss' in k)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /content/drive/My Drive/jupyter/detr/transformers/models/criterion.py in forward(self, x, y)
#      24
#      25     def forward(self, x: Dict[str, Tensor], y: List[Dict[str, Tensor]]) -> Dict[str, Tensor]:
# ---> 26         ans = self.computeLoss(x, y)
#      27
#      28         for i, aux in enumerate(x['aux']):
#
# /content/drive/My Drive/jupyter/detr/transformers/models/criterion.py in computeLoss(self, x, y)
#      44         :return: a dictionary containing classification loss, bbox loss, and gIoU loss
#      45         """
# ---> 46         ids = self.matcher(x, y)
#      47         idx = self.getPermutationIdx(ids)
#      48
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /content/drive/My Drive/jupyter/detr/transformers/models/matcher.py in forward(self, x, y)
#      34         sizes = [len(t['boxes']) for t in y]
#      35
# ---> 36         ids = [linear_sum_assignment(c[i]) for i, c in enumerate(costMatrix.split(sizes, -1))]
#      37
#      38         return [(torch.as_tensor(i, dtype=torch.int64), torch.as_tensor(j, dtype=torch.int64)) for i, j in ids]
#
# /content/drive/My Drive/jupyter/detr/transformers/models/matcher.py in <listcomp>(.0)
#      34         sizes = [len(t['boxes']) for t in y]
#      35
# ---> 36         ids = [linear_sum_assignment(c[i]) for i, c in enumerate(costMatrix.split(sizes, -1))]
#      37
#      38         return [(torch.as_tensor(i, dtype=torch.int64), torch.as_tensor(j, dtype=torch.int64)) for i, j in ids]
#
# /usr/local/lib/python3.7/dist-packages/scipy/optimize/_lsap.py in linear_sum_assignment(cost_matrix, maximize)
#      91
#      92     if np.any(np.isneginf(cost_matrix) | np.isnan(cost_matrix)):
# ---> 93         raise ValueError("matrix contains invalid numeric entries")
#      94
#      95     cost_matrix = cost_matrix.astype(np.double)
#
# ValueError: matrix contains invalid numeric entries

# %% [markdown]
# # Testing

# %%
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]
CLASSES = [
    'N/A', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A',
    'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse',
    'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack',
    'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis',
    'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove',
    'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass',
    'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich',
    'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A',
    'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
    'toothbrush'
]
transform2 = transforms.Compose([
#     transforms.Resize(800),
    transforms.Resize((38, 38)),
    transforms.ToTensor(),
#     transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
def detect(im, model, transform):
    # mean-std normalize the input image (batch-size: 1)
    img = transform(im).unsqueeze(0)

    # demo model only support by default images with aspect ratio between 0.5 and 2
    # if you want to use images with an aspect ratio outside this range
    # rescale your image so that the maximum size is at most 1333 for best results
    assert img.shape[-2] <= 1600 and img.shape[-1] <= 1600, 'demo model only supports images up to 1600 pixels on each side'

    # propagate through the model
#     img = img.to(device)
    outputs = model(img)

    # keep only predictions with 0.7+ confidence
    probas = outputs['class'].softmax(-1)[0, :, :-1]
    keep = probas.max(-1).values > 0.7

    # convert boxes from [0; 1] to image scales
    bboxes_scaled = rescale_bboxes(outputs['bbox'][0, keep], im.size)
    return probas[keep], bboxes_scaled

# %%
chk = torch.load('/home/daniel/Documents/coco/Modified-DETR/checkpoint/mango.pt', map_location=torch.device("cpu"))

model.load_state_dict(chk)
cpu_model = model.to('cpu')
# is_cuda(cpu_model)
model.eval();

# %%
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
im = Image.open(requests.get(url, stream=True).raw)

scores, boxes = detect(im, cpu_model, transform2)

# %%
dataiter = iter(dataloader)
images, labels = dataiter.next()

# %%
plt.imshow(np.transpose(images[1].numpy(), (1,2,0)))

# %%
CLASSES[labels[1]['labels'][-1]]

# %%
loaded_outputs = cpu_model(images)
probas = loaded_outputs['class'].softmax(-1)[0, :, :-1]
probas.max(-1).values


# tensor([0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997, 0.1997,
#         0.1997], grad_fn=<MaxBackward0>)

# %% [markdown]
# # Demo

# %%
train_dir = os.path.join(BASE_PATH, 'data/coco_mini/trainset')
ann_dir = os.path.join(BASE_PATH, 'data/coco_mini/instances_minitrain2017.json')

dataset = COCODataset(train_dir,
                      ann_dir,
                      608, # 608
                      608, # 608
                      args.numClass)
dataloader = DataLoader(dataset,
                        batch_size=1,
                        shuffle=False,
                        collate_fn=collateFunction,
                        pin_memory=True,
                        num_workers=args.numWorkers)

# %%
from torch import nn
class DETRdemo(nn.Module):
    """
    Demo DETR implementation.

    Demo implementation of DETR in minimal number of lines, with the
    following differences wrt DETR in the paper:
    * learned positional encoding (instead of sine)
    * positional encoding is passed at input (instead of attention)
    * fc bbox predictor (instead of MLP)
    The model achieves ~40 AP on COCO val5k and runs at ~28 FPS on Tesla V100.
    Only batch size 1 supported.
    """
    def __init__(self, num_classes, hidden_dim=256, nheads=8,
                 num_encoder_layers=6, num_decoder_layers=6):
        super().__init__()

        # create ResNet-50 backbone
        self.backbone = resnet50()
        del self.backbone.fc

        # create conversion layer
        self.conv = nn.Conv2d(2048, hidden_dim, 1)

        # create a default PyTorch transformer
        self.transformer = nn.Transformer(
            hidden_dim, nheads, num_encoder_layers, num_decoder_layers)

        # prediction heads, one extra class for predicting non-empty slots
        # note that in baseline DETR linear_bbox layer is 3-layer MLP
        self.linear_class = nn.Linear(hidden_dim, num_classes + 1)
        self.linear_bbox = nn.Linear(hidden_dim, 4)

        # output positional encodings (object queries)
        self.query_pos = nn.Parameter(torch.rand(100, hidden_dim))

        # spatial positional encodings
        # note that in baseline DETR we use sine positional encodings
        self.row_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))
        self.col_embed = nn.Parameter(torch.rand(50, hidden_dim // 2))

    def forward(self, inputs):
        # propagate inputs through ResNet-50 up to avg-pool layer
        x = self.backbone.conv1(inputs)
        x = self.backbone.bn1(x)
        x = self.backbone.relu(x)
        x = self.backbone.maxpool(x)

        x = self.backbone.layer1(x)
        x = self.backbone.layer2(x)
        x = self.backbone.layer3(x)
        x = self.backbone.layer4(x)

        # convert from 2048 to 256 feature planes for the transformer
        h = self.conv(x)

        # construct positional encodings
        H, W = h.shape[-2:]
        pos = torch.cat([
            self.col_embed[:W].unsqueeze(0).repeat(H, 1, 1),
            self.row_embed[:H].unsqueeze(1).repeat(1, W, 1),
        ], dim=-1).flatten(0, 1).unsqueeze(1)

        # propagate through the transformer
        h = self.transformer(pos + 0.1 * h.flatten(2).permute(2, 0, 1),
                             self.query_pos.unsqueeze(1)).transpose(0, 1)
        
        # finally project transformer outputs to class labels and bounding boxes
        return {'pred_logits': self.linear_class(h), 
                'pred_boxes': self.linear_bbox(h).sigmoid()}

# %%
from torchvision.models import resnet50

detr = DETRdemo(num_classes=91) 
state_dict = torch.hub.load_state_dict_from_url(
    url='https://dl.fbaipublicfiles.com/detr/detr_demo-da2a99e9.pth',
    map_location='cpu', check_hash=True)
detr.load_state_dict(state_dict)
detr.eval();

# %%
def box_cxcywh_to_xyxy2(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes2(out_bbox, size):
    _, _, img_w, img_h = size
    b = box_cxcywh_to_xyxy2(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
def detectDemo(im, model, transform):
    # mean-std normalize the input image (batch-size: 1)
#     img = transform(im)
    img = im

    # demo model only support by default images with aspect ratio between 0.5 and 2
    # if you want to use images with an aspect ratio outside this range
    # rescale your image so that the maximum size is at most 1333 for best results
    assert img.shape[-2] <= 1600 and img.shape[-1] <= 1600, 'demo model only supports images up to 1600 pixels on each side'

    # propagate through the model
#     img = img.to(device)
    outputs = model(img)

    # keep only predictions with 0.7+ confidence
    probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
    keep = probas.max(-1).values > 0.7

    # convert boxes from [0; 1] to image scales
    bboxes_scaled = rescale_bboxes2(outputs['pred_boxes'][0, keep], im.size())
    return probas[keep], bboxes_scaled

# %%
transform2(example[0].numpy())

# %%
example = iter(dataloader).next()[0]
scores, boxes = detectDemo(example, detr, transform2)

# %%
sample_image =  np.transpose(example[0].numpy(), (1,2,0))

# %%
def plot_results(pil_img, prob, boxes):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), COLORS * 100):
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        cl = p.argmax()
        text = f'{CLASSES[cl]}: {p[cl]:0.2f}'
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()
    
plot_results(example[0][0], scores, boxes)
