# %%
# !nvidia-smi
# Out:
# Sun May  2 12:39:12 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !unzip "/content/drive/My Drive/jupyter/yolo_coco/yolov5.zip" -d "/content/yolo";
# !unzip "/content/drive/My Drive/jupyter/yolo_coco/10k_coco.zip" -d "/content/yolo";
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/yolo/10k_coco/labels/train/000000362498.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000362614.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000362853.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363080.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363150.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363344.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363399.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363432.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363541.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363548.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363574.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363652.txt
#   inflating: /content/yolo/10k_coco/labels/train/000000363747.txt
# ...

# %% [markdown]
# find . -type f -name '._*' -delete

# %%
# %cd /content/yolo/yolov5

# !python train.py \
# --resume "/content/drive/My Drive/jupyter/results/yolov5s_200ep_bs32_10k_coco_new/weights/last.pt" \
# --project='/content/drive/My Drive/jupyter/results' \
# --save_dir='/content/drive/My Drive/jupyter/results/yolov5s_200ep_bs32_10k_coco_new'

# !python train.py --img 416 --batch 32 --epochs 200 --data "10k_coco.yaml" --weights yolov5s.pt \
--project='/content/drive/My Drive/jupyter/results' \
--save_dir='/content/drive/My Drive/jupyter/results/yolov5s_200ep_bs32_10k_coco_new'

# !python train.py --img 416 --batch 32 --epochs 1 --data "10k_coco.yaml" --weights yolov5s.pt \
# --project='/content/drive/My Drive/jupyter/results' \
# --save_dir='/content/drive/My Drive/jupyter/results/testttt'
# Out:
# /content/yolo/yolov5
# github: skipping check (not a git repository)
# fatal: not a git repository (or any of the parent directories): .git
# YOLOv5 🚀 2021-4-3 torch 1.8.1+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=32, bbox_interval=-1, bucket='', cache_images=False, cfg='', data='./data/10k_coco.yaml', device='', entity=None, epochs=200, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.yaml', image_weights=False, img_size=[416, 416], linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='/content/drive/My Drive/jupyter/results', quad=False, rect=False, resume=False, save_dir='/content/drive/My Drive/jupyter/results/yolov5s_200ep_bs32_10k_coco_new', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=32, upload_dataset=False, weights='yolov5s.pt', workers=8, world_size=1)
# ...

# %%
# %cd /content/yolo/yolov5
# !python test.py --img 416 --batch 64 --data "10k_coco.yaml" --weights yolov5s.pt \
--iou-thres 0.7 --task 'test'
# --project='/content/drive/My Drive/jupyter/results' \

# %%
# %cd /content/yolo/yolov5
# !wget https://farm2.staticflickr.com/1127/3163527001_429e51a258_z.jpg
# Out:
# /content/yolo/yolov5
# --2021-05-02 12:40:35--  https://farm2.staticflickr.com/1127/3163527001_429e51a258_z.jpg
# Resolving farm2.staticflickr.com (farm2.staticflickr.com)... 13.35.30.221, 2600:9000:213e:1000:0:5a51:64c9:c681, 2600:9000:213e:400:0:5a51:64c9:c681, ...
# Connecting to farm2.staticflickr.com (farm2.staticflickr.com)|13.35.30.221|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [image/jpeg]
# Saving to: ‘3163527001_429e51a258_z.jpg.1’
#
# 3163527001_429e51a2     [ <=>                ] 114.21K  --.-KB/s    in 0.008s
#
# 2021-05-02 12:40:35 (13.9 MB/s) - ‘3163527001_429e51a258_z.jpg.1’ saved [116955]

# %%
# !python detect.py --source '3163527001_429e51a258_z.jpg' --img-size 416 --conf 0.25 --iou 0.45 \
--weights 'yolov5s.pt'
# --weights '/content/drive/My Drive/jupyter/results/yolov5x_200ep_bs32_10k_coco_new/weights/best.pt' 

# P100
# s - Done. (0.027s), 0.027s
# m - Done. (0.032s), 0.032s
# l - Done. (0.041s), 0.041s
# x - Done. (0.049s), 0.048s

# V100
# s - Done. (0.029s), 0.026s
# m - Done. (0.032s), 0.031s
# l - Done. (0.033s), 0.035s
# x - Done. (0.036s), 0.036s
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', nosave=False, project='runs/detect', save_conf=False, save_txt=False, source='3163527001_429e51a258_z.jpg', update=False, view_img=False, weights=['yolov5s.pt'])
# fatal: not a git repository (or any of the parent directories): .git
# YOLOv5 🚀 2021-4-3 torch 1.8.1+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7266973 parameters, 0 gradients, 17.0 GFLOPS
# image 1/1 /content/yolo/yolov5/3163527001_429e51a258_z.jpg: 288x416 1 person, 1 couch, 1 tv, 2 laptops, 1 clock, Done. (0.009s)
# Results saved to runs/detect/exp10
# Done. (0.029s)
